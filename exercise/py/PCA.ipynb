# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
import numpy as np
from sklearn.decomposition import PCA

# %%
beta1=[1,1]
beta2=[-1,1]

# %%
fn=stats.norm()

# %%
alpha1=fn.rvs(size=100)+1

# %%
alpha2=fn.rvs(size=100)*0.01+2

# %%
np.matrix(alpha1).T*np.matrix(beta1)

# %%
np.matrix(beta1)
# Out:
# matrix([[1, 1]])

# %%
X=np.matrix(alpha1).T*np.matrix(beta1)+np.matrix(alpha2).T*np.matrix(beta2)

# %%
pca=PCA()

# %%
pca.fit(X)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
pca.components_
# Out:
# array([[-0.70763114, -0.70658203],
#        [-0.70658203,  0.70763114]])

# %%
np.sqrt(pca.explained_variance_)
# Out:
# array([ 1.45268054,  0.01582526])

# %%
X=np.asarray([np.cos(np.linspace(0,2*np.pi*10,100)),np.sin(np.linspace(0,2*np.pi*10,100))])

# %%
plt.plot(X[0])
plt.plot(X[1])

# %%
pca=PCA(n_components=2)

# %%
pca.fit(X.T)
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
pca.explained_variance_
# Out:
# array([ 0.5049,  0.495 ])

# %%
pca.components_
# Out:
# array([[-1., -0.],
#        [-0., -1.]])

# %%
np.corrcoef(X[0],X[1])*X[0].std()*X[1].std()
# Out:
# array([[  4.99925494e-01,   1.23234756e-16],
#        [  1.23234756e-16,   4.99925494e-01]])
